# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import seaborn as sns
import ipywidgets as ipyw

import pickle

from helpers.clusering_helpers import *
from helpers.plotting_helpers import *
from helpers.load_helpers import *

# %%
sns.set()
# %matplotlib notebook

# %% [markdown]
# # Data Loading

# %% [markdown]
# The segmentation file has to be in the data folder with name data/{filename}\_segmented.csv

# %% [markdown]
# ## Select a File
# Write the name of the file to be tracked (csv segmentation file has to be in data)

# %%
filename = "20200210_162333_SJR3.1.1_w1_s1_IAA"

# %% [markdown]
# ## Train from Scatch

# %%
segmented_df = load_files(filename)

# %% [markdown]
# ## Load already clustered

# %%
clustered_df = load_files(filename,already_clustered = True)

# %% [markdown]
# # Recording Motion Visualization

# %%
plot_through_time(clustered_df)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# # Clustering

# %%
df= segmented_df.copy()
refs_df,clustered_df,uncorrected,classifier = neurons_tracking(df,filename = filename)
# Out:
# the number of feature is : 10
# Saved at ../produced/20200210_162333_SJR3.1.1_w1_s1_IAA_clusters.p

# %% [markdown]
# # Results Visualization
#
# This assumes that an exported version of the nd2 recording in the tif format is in data/{filename}\_exported/

# %%
# %matplotlib inline
nd2_read(filename,clustered_df,path = "../data/")
# Out:
# interactive(children=(IntSlider(value=71, description='t', max=142), IntSlider(value=17, description='z', max=…

# %% [markdown]
# # Hand correction

# %%
corrected = clustered_df.copy()

# %%
update_cluster(corrected,26,27)

# %%
# %matplotlib inline
nd2_read(filename,corrected,path = "../../Semester_Project/data/")
# Out:
# interactive(children=(IntSlider(value=71, description='t', max=142), IntSlider(value=17, description='z', max=…
