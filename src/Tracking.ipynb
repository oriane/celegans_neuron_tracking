# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from mpl_toolkits import mplot3d
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as ipyw

import pickle

from helpers.clusering_helpers import *
from helpers.plotting_helpers import *
from helpers.load_helpers import *

# %%
sns.set()
# %matplotlib notebook

# %% [markdown]
# # Data Loading

# %% [markdown]
# Available Files :
# - Video imobilized with ground_truth :
#     - 20200210_162333_SJR3.1.1_w1_s1_IAA
# - Video imobilized :
#     - 20191031_SJR5.3_with_AIY_w1_s3
#     - 20190805_SJR3.2.2_w1_s4 (messy) t=78
#     - 20191113_SJR5.3_with_AIY_w1_s1
# - Video freely moving :
#     - 20200228_164816_SJR4.2.2_3h_30C_w1_s1_IAA

# %% [markdown]
# ## Select a File
# Copy one of the name of the list above (or any file whose segmented result in on the ../data folder)

# %%
filename = "20200210_162333_SJR3.1.1_w1_s1_IAA"

# %% [markdown]
# ## Train from Scatch

# %%
segmented_df = load_files(filename)

# %% [markdown]
# ## Load already clustered

# %%
clustered_df = load_files(filename,already_clustered = True)

# %% [markdown]
# # Recording Motion Visualization

# %%
plot_through_time(clustered_df)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# # Clustering

# %%
df= segmented_df.copy()
refs_df,clustered_df,uncorrected,classifier = neurons_tracking(df,filename = filename)
# Out:
# the number of feature is : 10
# Saved at ../produced/20190805_SJR3.2.2_w1_s4_clusters.p

# %% [markdown]
# # Results Visualization

# %%
# %matplotlib inline
nd2_read(filename,clustered_df,path = "../../Semester_Project/data/")
# Out:
# interactive(children=(IntSlider(value=71, description='t', max=142), IntSlider(value=17, description='z', max=…

# %% [markdown]
# # Hand correction

# %%
corrected = clustered_df.copy()

# %%
update_cluster(corrected,26,27)

# %%
# %matplotlib inline
nd2_read(filename,corrected,path = "../../Semester_Project/data/")
# Out:
# interactive(children=(IntSlider(value=71, description='t', max=142), IntSlider(value=17, description='z', max=…
